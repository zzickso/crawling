# %% [markdown]
# #### 이커머스(지마켓) 베스트 100 상품 타이틀/가격 추출하기

# %%
import requests
from bs4 import BeautifulSoup
import re

res = requests.get('http://corners.gmarket.co.kr/Bestsellers?viewType=G&groupCode=G06')
soup = BeautifulSoup(res.content, 'html.parser')
bestlists = soup.select('div.best-list')
bestitems = bestlists[1]
products = bestitems.select('ul li')

for index, product in enumerate(products):
    number = product.select_one('p')
    title = product.select_one('a.itemname')
    price = product.select_one('strong')
    print(number.get_text(), title.get_text(), price.get_text(), title['href'])
# Out:
# 1 [자우버]렌즈케어 200매 렌즈클리너 일회용 안경닦이 티슈 9,400원 http://item.gmarket.co.kr/Item?goodscode=797037966&ver=637559928032859766
# 2 닌텐도 스위치 슈퍼 마리오 3D 월드 + 퓨리 월드 c 59,020원 http://item.gmarket.co.kr/Item?goodscode=2007957912&ver=637559928032859766
# 3 [샤오미]xiaomi 미TV 스틱/1080P/한국어 지원/글로벌 버전 41,200원 http://item.gmarket.co.kr/Item?goodscode=1994586227&ver=637559928032859766
# 4 [유닉스]메탈티 무광블랙 1600W 헤어 드라이기 UN-A1610 접이식 21,900원 http://item.gmarket.co.kr/Item?goodscode=1824005992&ver=637559928032859766
# 5 [비달사순]비달사순 2000W 전문가용 헤어드라이기 VSD5129K 20,800원 http://item.gmarket.co.kr/Item?goodscode=1807976048&ver=637559928032859766
# 6 [닌텐도]스위치 슈퍼 마리오 파티 58,900원 http://item.gmarket.co.kr/Item?goodscode=1853251769&ver=637559928032859766
# 7 [쉴드플러스]21년형+10%쿠폰)최고급형 써큘레이터 선풍기 리모컨 37,900원 http://item.gmarket.co.kr/Item?goodscode=2099672668&ver=637559928032859766
# 8 (21년형+10%쿠폰)르젠 2세대 BLDC 선풍기 LZEF-DC02 69,800원 http://item.gmarket.co.kr/Item?goodscode=1829671455&ver=637559928032859766
# ...

# %% [markdown]
# #### 테스트

# %%
import requests
from bs4 import BeautifulSoup

res = requests.get('http://corners.gmarket.co.kr/Bestsellers?viewType=G&groupCode=G06')
soup = BeautifulSoup(res.content, 'html.parser')
items =soup.select('div.best-list ul li a.itemname')
for item in items:
    print(item.get_text())
# Out:
# [자우버]렌즈케어 200매 렌즈클리너 일회용 안경닦이 티슈
# 닌텐도 스위치 슈퍼 마리오 3D 월드 + 퓨리 월드 c
# [샤오미]xiaomi 미TV 스틱/1080P/한국어 지원/글로벌 버전
# [유닉스]메탈티 무광블랙 1600W 헤어 드라이기 UN-A1610 접이식
# [닌텐도]스위치 슈퍼 마리오 파티
# [비달사순]비달사순 2000W 전문가용 헤어드라이기 VSD5129K
# [쉴드플러스]21년형+10%쿠폰)최고급형 써큘레이터 선풍기 리모컨
# 네스프레소 에센자 C30 XN1101 미니 커피머신
# (21년형+10%쿠폰)르젠 2세대 BLDC 선풍기 LZEF-DC02
# [단미]샌드위치 크로플 와플 메이커 화이트(DA-SAN01)
# [유닉스]메탈릭 레트로 파워맥스 2000W 헤어드라이기 UN-B1643
# [삼성전자]갤럭시 핏2 SM-R220 스마트밴드 10%할인
# 최신형) 무선 셀카봉 블루투스 핸드폰 삼각대 거치대
# [일렉트로룩스](최초가 469000원) 18V 파워PRO ZB3423BO
# 은성전기 실버스티머 SR-5000 매장정품스팀다리미
# [닌텐도]C 닌텐도 SWITCH 모여봐요 동물의 숲 한글판
# 가죽 지갑 다이어리 아이폰 갤럭시 LG 핸드폰 케이스
# 23L 대용량 에어프라이어오븐 DM-AF1 로티세리 통돌이
# [대우]대우 에어 써큘레이터DEF-KC1020스탠드선풍기 공기순환
# (빠른직구)ALLDOCUBE iplay40 태블릿 8+128G글로벌버전
# [비달사순]비달사순 에어 봉고데기/매직기/아이롱 VSAS80PIK
# [닌텐도]닌텐도 모여봐요 동물의 숲 SWITCH 한글판 C
# [신일전자]신일 다용도 미니 소형 블렌더 믹서기 SMX-MB2B
# [닌텐도]닌텐도 모여봐요 동물의 숲(SWITCH)
# [필립스](최종 364000원) 1200 에스프레소 커피머신 EP1200/03
# 샤오미 스마트 자동 유리창 창문 로봇청소기 화이트
# [한경희생활과학]한경희 5L 올스텐304 바스켓 에어프라이어 HE-A817 / R
# ...

# %% [markdown]
# #### 품명과 링크가 안걸린다 ㅠ

# %%
import re
import requests
from bs4 import BeautifulSoup

res = requests.get('http://corners.gmarket.co.kr/Bestsellers?viewType=G&groupCode=G06')
soup = BeautifulSoup(res.content, 'html.parser')
items =soup.select('div.best-list')
product = items[1]
products = product.select('ul li')
for item in products:
    print('순위:',item.find('p').get_text(),'품명:', item.find('a').get_text, '현재가:',item.find('strong').get_text(),
         '링크:',item.find('a').get_text)
# Out:
# 순위: 1 품명: <bound method Tag.get_text of <a href="http://item.gmarket.co.kr/Item?goodscode=797037966&amp;ver=637559845325223833" onclick="pdsClickLog('200000680', 'Item', {'ASN': 1, 'goodsCode': '797037966'});"><img alt="[자우버]렌즈케어 200매 렌즈클리너 일회용 안경닦이 티슈" class="lazy" data-original="http://gdimg.gmarket.co.kr/797037966/still/300" height="210" src="http://image.gmarket.co.kr/challenge/neo_image/no_image.gif" width="210"/></a>> 현재가: 9,400원 링크: <bound method Tag.get_text of <a href="http://item.gmarket.co.kr/Item?goodscode=797037966&amp;ver=637559845325223833" onclick="pdsClickLog('200000680', 'Item', {'ASN': 1, 'goodsCode': '797037966'});"><img alt="[자우버]렌즈케어 200매 렌즈클리너 일회용 안경닦이 티슈" class="lazy" data-original="http://gdimg.gmarket.co.kr/797037966/still/300" height="210" src="http://image.gmarket.co.kr/challenge/neo_image/no_image.gif" width="210"/></a>>
# ...
